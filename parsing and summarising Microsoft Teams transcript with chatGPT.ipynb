# %% [markdown]
# # Parsing and summarising Microsoft Teams transcript
# with help from chatGPT

# %%
import pandas as pd

file = "ms_teams_transcript.vtt"

df = pd.read_csv(file,error_bad_lines=False,header=None)

df_filtered = df[~df[0].str.contains('-->')].reset_index(drop=True)
df_filtered2 = df_filtered[~df_filtered[0].str.contains('6cce57e5-c4fb-49fa-8560-ce4eeda3a7d9')].reset_index(drop=True)

text = df_filtered2[0].str.cat(sep=' ')
# Out:
# <ipython-input-45-73982c0b50f2>:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file,error_bad_lines=False,header=None)
# ...
